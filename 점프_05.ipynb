# %%
import time
time.time()
# Out:
# 1707888610.6570678

# %%
time.localtime(time.time())
# Out:
# time.struct_time(tm_year=2024, tm_mon=2, tm_mday=14, tm_hour=5, tm_min=30, tm_sec=19, tm_wday=2, tm_yday=45, tm_isdst=0)
