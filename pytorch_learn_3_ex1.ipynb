# %%
#numpy
#Numpy 연산을 사용하여 신경망의 순전파 단계와 역전파 단계를 직접 구현함으로써, 3차 다항식이 사인 함수에 근사

#import
import numpy as np
import math

#무작위로 입력과 출력 데이터를 생성합니다.
x = np.linspace(-math.pi, math.pi, 2000)
y = np.sin(x)

#무작위로 가중치를 초기화
a = np.random.randn()
b = np.random.randn()
c = np.random.randn()
d = np.random.randn()

learning_rate = 1e-6
for t in range(2000):
    #순전파
    y_pred = a + b*x + c*x**2 + d*x**3

    #손실
    loss = np.square(y_pred - y).sum()
    if t % 100 == 99:
        print(t,loss)

    #손실에 따른 a,b,c,d의 변화도(gradient)를 계산하고 역전파합니다.
    grad_y_pred = 2.0 * (y_pred - y)
    grad_a = grad_y_pred.sum()
    grad_b = (grad_y_pred * x).sum()
    grad_c = (grad_y_pred * x**2).sum()
    grad_d = (grad_y_pred * x**3).sum()

    # 가중치 갱신
    a -= learning_rate * grad_a
    b -= learning_rate * grad_b
    c -= learning_rate * grad_c
    d -= learning_rate * grad_d

print(f'Result: y = {a} + {b}x + {c} x^2 + {d} x^3')
# Out:
# 99 363.5729863361725
# 199 246.98979365223724
# 299 168.8495510828322
# 399 116.43653913845971
# 499 81.25280722353152
# 599 57.61560255511435
# 699 41.722281025692816
# 799 31.02655377817247
# 899 23.82219072886501
# 999 18.965027478022325
# 1099 15.68721965947472
# 1199 13.473058013481218
# 1299 11.975888261388036
# 1399 10.9624930154901
# 1499 10.275832152976193
# 1599 9.810063683744668
# 1699 9.493784845055897
# 1799 9.278779409670125
# 1899 9.132455929761548
# 1999 9.03276196084853
# Result: y = 0.011022222535164423 + 0.8466778694231016x + -0.0019015167978905251 x^2 + -0.09189901866793473 x^3
