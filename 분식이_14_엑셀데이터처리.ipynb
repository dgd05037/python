# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

import sys
if 'google.colab' in sys.modules:
    # !echo 'debconf debconf/fronted select Noninteractive' | debconf-set-selections
    # !sudo apt-get -qq -y install fonts-nanum
    import matplotlib.font_manager as fm
    font_files = fm.findSystemFonts(fontpaths=['/usr/share/fonts/truetype/nanum'])
    for fpath in font_files:
        fm.fontManager.addfont(fpath)
# Out:
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121749 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
mpl.rc('font', family = 'NanumGothic')

# %%
df1 = pd.read_csv('Data09.csv', encoding = 'cp949')
print(df1.shape)
df1.head(2)
# Out:
# (117, 646)
#    순번  상품코드  상품명         합계 (1154)의정부점 (1155)별내점 (1156)풍산점 (1157)김포한강점  \
# 0 NaN   NaN  NaN         수량         수량        수량        수량          수량
# 1 NaN   NaN  합 계  2,029,096      6,829     8,374    12,626      11,767
#
#   (1158)세종점 (1159)킨텍스점  ... (L21)위시티점 (L23)걸포동점 (L27)통일동산점 (L35)성대점 (L36)병점점  \
# 0        수량         수량  ...        수량        수량         수량       수량       수량
# 1    10,912      7,062  ...     2,392     1,291      4,506    2,364    2,739
#
#   (L38)율전점 (L39)본오점 (L40)검암점 (L44)신길점 (L46)용호점
# 0       수량       수량       수량       수량       수량
# 1    1,782    3,129    1,712    3,189    2,347
#
# [2 rows x 646 columns]

# %%
df2=df1.drop(0).T
df2
# Out:
#                   1               2               3           4           5    \
# 순번                NaN             1.0             2.0         3.0         4.0
# 상품코드              NaN       1801828.0       1801859.0  40786179.0  41001356.0
# 상품명               합 계  BW1 473ml캔(수입)  BW1 355ml (낱캔)    RB 500ml    VX 500ml
#  합계         2,029,096          65,402               1       2,158       3,649
# (1154)의정부점      6,829             174               0           4          14
# ...               ...             ...             ...         ...         ...
# (L38)율전점        1,782              72               0           0           0
# (L39)본오점        3,129              15               0           0           0
# (L40)검암점        1,712              38               0           0           0
# (L44)신길점        3,189              27               0           0           0
# (L46)용호점        2,347              89               0           0           0
#
#                    6                              7              8    \
# 순번                 5.0                            6.0            7.0
# 상품코드        88005324.0                  18200004735.0  18200250002.0
# 상품명         CAT2 500ml  BW1 473ml(알루미늄)_2018 Worldcup      BW1 740ml
#  합계                  1                         47,934         40,381
# (1154)의정부점           0                            258            651
# ...                ...                            ...            ...
# (L38)율전점             0                              0             21
# (L39)본오점             0                              0             26
# (L40)검암점             0                              0             10
# (L44)신길점             0                              0             29
# (L46)용호점             0                              0            123
#
#                           9                 10   ...  \
# 순번                        8.0               9.0  ...
# 상품코드            18200966583.0    736920000000.0  ...
# 상품명         BW1 473ml*24캔 ALU  G1아일랜드 IPA 355ml  ...
#  합계                        55                 6  ...
# (1154)의정부점                  0                 0  ...
# ...                       ...               ...  ...
# (L38)율전점                    0                 0  ...
# (L39)본오점                    0                 0  ...
# (L40)검암점                    0                 0  ...
# (L44)신길점                    0                 0  ...
# (L46)용호점                    0                 0  ...
#
#                                   107              108  \
# 순번                              106.0            107.0
# 상품코드                  8801860000000.0  8801860000000.0
# 상품명         CAT1 250ml*10*2 [Traders]       CAT2 250ml
#  합계                             6,347              162
# (1154)의정부점                          0                0
# ...                               ...              ...
# (L38)율전점                            0                0
# (L39)본오점                            0                0
# (L40)검암점                            0                0
# (L44)신길점                            0                0
# (L46)용호점                            0                0
#
#                                   109                 110  \
# 순번                              108.0               109.0
# 상품코드                  8801860000000.0     8801860000000.0
# 상품명         CAT1 48캔+신라면 멀티 [Traders]  CAT2 355ml*24캔+진라면
#  합계                                 1                   2
# (1154)의정부점                          0                   0
# ...                               ...                 ...
# (L38)율전점                            0                   0
# (L39)본오점                            0                   0
# (L40)검암점                            0                   0
# (L44)신길점                            0                   0
# (L46)용호점                            0                   0
#
#                             111                       112  \
# 순번                        110.0                     111.0
# 상품코드            8801860000000.0           8801860000000.0
# 상품명         CAT1 355*12캔 카카오쿨러백  CAT1 355ml*12캔+카카오 에코백+치
#  합계                       2,135                       179
# (1154)의정부점                   26                         0
# ...                         ...                       ...
# (L38)율전점                      0                         0
# (L39)본오점                      0                         0
# (L40)검암점                      0                         0
# (L44)신길점                      0                         0
# (L46)용호점                      0                         0
#
#                               113              114              115  \
# 순번                          112.0            113.0            114.0
# 상품코드              8801860000000.0  8801860000000.0  8801860000000.0
# 상품명         CAT2 355*24캔 + 진라면 6캔      CAT2 1.6L*6        CAT2 1.6L
#  합계                           212            6,564          125,144
# (1154)의정부점                      0                0              365
# ...                           ...              ...              ...
# (L38)율전점                        0                0              128
# (L39)본오점                        0                0              354
# (L40)검암점                        0                0              106
# (L44)신길점                        0                0              242
# (L46)용호점                        0                0              122
#
#                         116
# 순번                    115.0
# 상품코드        8801860000000.0
# 상품명               CAT1 1.6L
#  합계                  22,796
# (1154)의정부점              113
# ...                     ...
# (L38)율전점                 54
# (L39)본오점                 28
# (L40)검암점                  9
# (L44)신길점                 28
# (L46)용호점                 24
#
# [646 rows x 116 columns]

# %%
print(df2.index)
# Out:
# Index(['순번', '상품코드', '상품명', ' 합계', '(1154)의정부점', '(1155)별내점', '(1156)풍산점',
#        '(1157)김포한강점', '(1158)세종점', '(1159)킨텍스점',
#        ...
#        '(L21)위시티점', '(L23)걸포동점', '(L27)통일동산점', '(L35)성대점', '(L36)병점점',
#        '(L38)율전점', '(L39)본오점', '(L40)검암점', '(L44)신길점', '(L46)용호점'],
#       dtype='object', length=646)

# %%
df2.drop('순번').drop('상품코드').sort_values(by = 1,ascending=True)
# Out:
#                  1               2               3         4         5    \
# (2762)F경주용강점   1,065              58               0         0         0
# (2332)부산신호점    1,082              20               0         0         0
# (A23)장기동점      1,099              50               0         0         0
# (2763)F창원북면점   1,102              62               0         0         0
# (2322)기흥점      1,171              25               0         0         0
# ...              ...             ...             ...       ...       ...
# (2668)명지SF점      958              36               0         0         0
# (2032)방배효령점      965              72               0         0         0
# (1638)NB대전세이점     98              24               0         0         0
# (2524)남양주도곡점     983              31               0         0         0
# 상품명              합 계  BW1 473ml캔(수입)  BW1 355ml (낱캔)  RB 500ml  VX 500ml
#
#                       6                              7          8    \
# (2762)F경주용강점            0                              0         33
# (2332)부산신호점             0                              0         18
# (A23)장기동점               0                              0         20
# (2763)F창원북면점            0                              0         26
# (2322)기흥점               0                              0         41
# ...                   ...                            ...        ...
# (2668)명지SF점             0                              0          3
# (2032)방배효령점             0                              0          8
# (1638)NB대전세이점           0                              0          0
# (2524)남양주도곡점            0                              0         22
# 상품명            CAT2 500ml  BW1 473ml(알루미늄)_2018 Worldcup  BW1 740ml
#
#                              9                 10   ...  \
# (2762)F경주용강점                   0                 0  ...
# (2332)부산신호점                    0                 0  ...
# (A23)장기동점                      0                 0  ...
# (2763)F창원북면점                   0                 0  ...
# (2322)기흥점                      0                 0  ...
# ...                          ...               ...  ...
# (2668)명지SF점                    0                 0  ...
# (2032)방배효령점                    0                 0  ...
# (1638)NB대전세이점                  0                 0  ...
# (2524)남양주도곡점                   0                 0  ...
# 상품명            BW1 473ml*24캔 ALU  G1아일랜드 IPA 355ml  ...
#
#                                      107         108  \
# (2762)F경주용강점                           0           0
# (2332)부산신호점                            0           0
# (A23)장기동점                              0           0
# (2763)F창원북면점                           0          33
# (2322)기흥점                              0           0
# ...                                  ...         ...
# (2668)명지SF점                            0           0
# (2032)방배효령점                            0           0
# (1638)NB대전세이점                          0           0
# (2524)남양주도곡점                           0           0
# 상품명            CAT1 250ml*10*2 [Traders]  CAT2 250ml
#
#                                      109                 110  \
# (2762)F경주용강점                           0                   0
# (2332)부산신호점                            0                   0
# (A23)장기동점                              0                   0
# (2763)F창원북면점                           0                   0
# (2322)기흥점                              0                   0
# ...                                  ...                 ...
# (2668)명지SF점                            0                   0
# (2032)방배효령점                            0                   0
# (1638)NB대전세이점                          0                   0
# (2524)남양주도곡점                           0                   0
# 상품명            CAT1 48캔+신라면 멀티 [Traders]  CAT2 355ml*24캔+진라면
#
#                                111                       112  \
# (2762)F경주용강점                     0                         0
# (2332)부산신호점                      0                         0
# (A23)장기동점                        0                         0
# (2763)F창원북면점                     0                         0
# (2322)기흥점                        0                         0
# ...                            ...                       ...
# (2668)명지SF점                      0                         0
# (2032)방배효령점                      0                         0
# (1638)NB대전세이점                    0                         0
# (2524)남양주도곡점                     0                         0
# 상품명            CAT1 355*12캔 카카오쿨러백  CAT1 355ml*12캔+카카오 에코백+치
#
#                                  113          114        115        116
# (2762)F경주용강점                       0            0         99         17
# (2332)부산신호점                        0            0         53         38
# (A23)장기동점                          0            0         81         27
# (2763)F창원북면점                       0            0         34          8
# (2322)기흥점                          0            0        103         33
# ...                              ...          ...        ...        ...
# (2668)명지SF점                        0            0         25          3
# (2032)방배효령점                        0            0         26         19
# (1638)NB대전세이점                      0            0          0          0
# (2524)남양주도곡점                       0            0         98         52
# 상품명            CAT2 355*24캔 + 진라면 6캔  CAT2 1.6L*6  CAT2 1.6L  CAT1 1.6L
#
# [644 rows x 116 columns]

# %%
df1.columns
# Out:
# Index(['순번', '상품코드', '상품명', ' 합계', '(1154)의정부점', '(1155)별내점', '(1156)풍산점',
#        '(1157)김포한강점', '(1158)세종점', '(1159)킨텍스점',
#        ...
#        '(L21)위시티점', '(L23)걸포동점', '(L27)통일동산점', '(L35)성대점', '(L36)병점점',
#        '(L38)율전점', '(L39)본오점', '(L40)검암점', '(L44)신길점', '(L46)용호점'],
#       dtype='object', length=646)

# %%
stack_data = df1.drop(columns=['순번','상품코드']).set_index('상품명').stack()

# %%
df2 = pd.DataFrame(stack_data).reset_index()

# %%
region_list = df1.columns.tolist()[4:]
pd.melt(df1, id_vars=['상품명'], value_vars = region_list)

# %%
df2.head(2)
# Out:
#    상품명     level_1   0
# 0  NaN          합계  수량
# 1  NaN  (1154)의정부점  수량

# %%
cond1 = (df2['상품명'].isnull())
cond2 = (df2['상품명']=='합 계')
cond3 = (df2['level_1'] != ' 합계')
df3=df2.loc[(~cond1)&(~cond2)&(cond3)]
df4=df3.rename(columns={'level_1':'점포명',0:'판매량'})
df4.head()
# Out:
#                  상품명          점포명  판매량
# 1287  BW1 473ml캔(수입)   (1154)의정부점  174
# 1288  BW1 473ml캔(수입)    (1155)별내점  239
# 1289  BW1 473ml캔(수입)    (1156)풍산점  432
# 1290  BW1 473ml캔(수입)  (1157)김포한강점  199
# 1291  BW1 473ml캔(수입)    (1158)세종점  220

# %%
df4['상품명'].unique()
# Out:
# array(['BW1 473ml캔(수입)', 'BW1 355ml (낱캔)', 'RB 500ml', 'VX 500ml',
#        'CAT2 500ml', 'BW1 473ml(알루미늄)_2018 Worldcup', 'BW1 740ml',
#        'BW1 473ml*24캔 ALU', 'G1아일랜드 IPA 355ml',
#        'G1 아일랜드 312 Wheat Ale 355ml', 'G1아일랜드 Sopie 355ml', 'GL LOLITA',
#        'Juliet', 'GL Gillian', 'GL HALIA', 'STL 500ml', 'B1 Grigio 250ml',
#        'BR 250ml', 'PRC 500ml', 'STLA 330*6캔(new code)', 'STL 330ml',
#        'RPB 330ml', 'RB1 500ml', 'HGD2 750ml', 'HGD 500캔 (수입)',
#        'HGD 330*6캔 (수입)', 'HGD3 500ml', 'HRB 500ml', 'HRB 500ml(신코드)',
#        'PTG 473ml캔', 'CFR 355ml*6', 'CFR 355ml', 'CFR 330ml(신)',
#        'OLB 355ml', 'OLB 355ml*6', 'OLB 500ml', 'FG 355ml', 'FG 355ml*6',
#        'FG 500ml', 'FG 500ml*24캔[Traders]', 'FG 1.6L', 'FG 355ml*12캔 쿠폰팩',
#        'OLB 355ml*6캔 PKG [골든크라운]', 'OLB 500ml캔 [골든크라운]',
#        'OLB 500ml병 [골든크라운]', 'OLB 1.6L [골든크라운]', 'OLB 355ml*12캔 + 전용잔2',
#        'OLB 355ml*12캔 + 쿨러백 (202006)', 'HGD 330ml', 'HGD 355ml*6',
#        'STL 500ml*4', 'CRN 355ml', 'HGD2 250ml', 'BW1 330ml(신)',
#        'BW1 740ml*3캔_Traders', 'BW1 355ml*6캔(수입)', 'STL 500ml*6캔_Traders',
#        'HGD 500ml*6캔_Traders', 'STL 330ml*12캔_Multi', 'CRN 355ml*6캔',
#        'G1 IPA 473ml캔', 'G1 312 473ml캔', 'BW1 237ml*8캔',
#        'BW1 237ml*12캔 PKG', 'MC1 500ml캔', 'RR 355ml*6캔',
#        'RR 355ml*24캔 [Traders]', 'CRN (2019)', 'HGD2 330ml*6캔',
#        'RR 355*6캔 + 전용잔 기획', 'G1 473ml*8캔 [Traders]',
#        'G1 IPA 473ml*4캔+전용잔', 'G1 IPA 473ml*6캔 [Traders]',
#        'HGD 750ml*3캔+50cl 전용잔', 'MC1 500ml*4캔+전용잔 [2020,03]',
#        'STL 500ml*6캔+스페셜 전용잔(2020 로맨틱)', 'PTG 473ml*6캔 [Traders]',
#        'STL 500ml*6캔+전용잔 [2020여성의날]', 'G1IPA 473ml*4캔+기획잔 [2020/03]',
#        'G1 312 473ml*4캔 + 전용잔 기획[2020.03]', 'HGD 500ml*6캔 + 레시피 노트',
#        'HGD3 500ml*4캔+', 'HGD3 500ml 캔 (202006)',
#        'STL *4캔+전용잔1(202006 2차)', 'G1 IPA 473ml*8캔 쿨러백',
#        'HGD 495ml*4 + 전용잔 [2020.07_국산]',
#        'G1 IPA 473ml*12캔 + 쿨러박스 [Traders]', 'CAT2 355ml', 'CAT1 355ml',
#        'CAT2 355ml*6', 'CAT2 355ml*24', 'CAT1 355ml*6', 'CAT1 1.0L',
#        'CAT1 500ml', 'CAT1 355ml*12', 'CAT2 355ml*24+쿨러백',
#        'CAT2 355ml*8 절약팩', 'CAT2 640ml(신)', 'CAT2 500ml(신)',
#        'CAT2 355ml*10캔(냉장패키지)', 'CAT2 250ml*10캔 냉장패키지',
#        'CAT1 250ml*10*2 [Traders]', 'CAT2 250ml',
#        'CAT1 48캔+신라면 멀티 [Traders]', 'CAT2 355ml*24캔+진라면',
#        'CAT1 355*12캔 카카오쿨러백', 'CAT1 355ml*12캔+카카오 에코백+치',
#        'CAT2 355*24캔 + 진라면 6캔', 'CAT2 1.6L*6', 'CAT2 1.6L', 'CAT1 1.6L'],
#       dtype=object)
