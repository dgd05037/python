# %%
import pandas as pd

s4 = pd.Series(['국어','수학','사회','과학'])
s4
# Out:
# 0    국어
# 1    수학
# 2    사회
# 3    과학
# dtype: object

# %%
s4[0]
# Out:
# '국어'

# %%
df1 = pd.DataFrame([[1000,'과자','2019-12-31','반품'],
                    [2000,'음료','2020-03-02','정상'],
                    [3000,'아이스크림','2020-02-03','정상'],
                    [1000,'과자','2019-12-31','반품']]
                   ,columns =['가격','종류','판매일자','반품여부'])
df1
# Out:
#      가격     종류        판매일자 반품여부
# 0  1000     과자  2019-12-31   반품
# 1  2000     음료  2020-03-02   정상
# 2  3000  아이스크림  2020-02-03   정상
# 3  1000     과자  2019-12-31   반품

# %%
df1['가격']
# Out:
# 0    1000
# 1    2000
# 2    3000
# 3    1000
# Name: 가격, dtype: int64

# %%
df1['종류']
# Out:
# 0       과자
# 1       음료
# 2    아이스크림
# 3       과자
# Name: 종류, dtype: object

# %%
df1['가격'].sum()
# Out:
# 7000

# %%
df1['가격'].mean()
# Out:
# 1750.0

# %%
df1[['가격']]
# Out:
#      가격
# 0  1000
# 1  2000
# 2  3000
# 3  1000

# %%
df1.loc(['가격':'판매일자'])
# Out:
#   File "<ipython-input-23-4310810dee85>", line 1
#     df1.loc(['가격':'판매일자'])
#                  ^
# SyntaxError: invalid syntax

# %%
df1 = pd.read_csv('example.csv')

# %%
df1.shape
# Out:
# (101740, 20)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101740 entries, 0 to 101739
# Data columns (total 20 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   공급일자      101740 non-null  object
#  1   요일        101740 non-null  object
#  2   공급월       101740 non-null  int64
#  3   공급주차      101740 non-null  int64
#  4   회원번호      101740 non-null  int64
#  5   조합원상태     101740 non-null  object
#  6   물품대분류     101740 non-null  object
#  7   물품중분류     101739 non-null  object
#  8   물품소분류     101739 non-null  object
#  9   물품명       101739 non-null  object
#  10  구매수량      101739 non-null  float64
#  11  주소-구      101739 non-null  object
#  12  주소-동      101739 non-null  object
#  13  성별        101739 non-null  object
#  14  연령        101739 non-null  float64
#  15  연령대       101739 non-null  object
#  16  구매금액      101739 non-null  float64
#  17  구매매장      101739 non-null  object
#  18  반품_원거래일자  1353 non-null    float64
#  19  구매시각      101739 non-null  object
# dtypes: float64(4), int64(3), object(13)
# memory usage: 15.5+ MB

# %%
df1
# Out:
#             공급월           공급주차          회원번호           구매수량             연령  \
# count  101740.0  101740.000000  1.017400e+05  101739.000000  101739.000000
# mean        1.0       2.459485  7.333214e+08       1.135373      50.461328
# std         0.0       1.068193  4.108099e+08       0.675830      11.171507
# min         1.0       1.000000  1.876416e+07     -10.000000      21.000000
# 25%         1.0       2.000000  3.976164e+08       1.000000      42.000000
# 50%         1.0       2.000000  7.459914e+08       1.000000      48.000000
# 75%         1.0       3.000000  1.029005e+09       1.000000      57.000000
# max         1.0       4.000000  1.670400e+09      30.000000     107.000000
#
#                 구매금액      반품_원거래일자
# count  101739.000000  1.353000e+03
# mean    10837.719272  2.017996e+07
# std     15258.657183  1.173253e+03
# min   -333108.000000  2.017123e+07
# 25%      4403.000000  2.018011e+07
# 50%      7275.000000  2.018012e+07
# 75%     12635.000000  2.018012e+07
# max    666216.000000  2.018013e+07

# %%
df1.isnull().sum()
# Out:
# 공급일자             0
# 요일               0
# 공급월              0
# 공급주차             0
# 회원번호             0
# 조합원상태            0
# 물품대분류            0
# 물품중분류            1
# 물품소분류            1
# 물품명              1
# 구매수량             1
# 주소-구             1
# 주소-동             1
# 성별               1
# 연령               1
# 연령대              1
# 구매금액             1
# 구매매장             1
# 반품_원거래일자    100387
# 구매시각             1
# dtype: int64

# %%
df1.columns
# Out:
# Index(['공급일자', '요일', '공급월', '공급주차', '회원번호', '조합원상태', '물품대분류', '물품중분류', '물품소분류',
#        '물품명', '구매수량', '주소-구', '주소-동', '성별', '연령', '연령대', '구매금액', '구매매장',
#        '반품_원거래일자', '구매시각'],
#       dtype='object')

# %%
df1['구매금액']
# Out:
# 0         22207.0
# 1          4977.0
# 2          7083.0
# 3           766.0
# 4          4403.0
#            ...
# 101735     7466.0
# 101736     4977.0
# 101737     9955.0
# 101738    21441.0
# 101739        NaN
# Name: 구매금액, Length: 101740, dtype: float64

# %%
df1['구매금액'].sum()
# Out:
# 1102618721.0

# %%
df1['구매금액'].describe()
# Out:
# count    101739.000000
# mean      10837.719272
# std       15258.657183
# min     -333108.000000
# 25%        4403.000000
# 50%        7275.000000
# 75%       12635.000000
# max      666216.000000
# Name: 구매금액, dtype: float64

# %%
df2= df1[['구매금액','성별']]

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=101740, step=1)

# %%
df1.values
# Out:
# array([['2018-01-02', '화', 1, ..., '매장C', nan, '10:04'],
#        ['2018-01-02', '화', 1, ..., '매장C', nan, '10:05'],
#        ['2018-01-02', '화', 1, ..., '매장C', nan, '10:05'],
#        ...,
#        ['2018-01-27', '토', 1, ..., '매장D', nan, '15:33'],
#        ['2018-01-27', '토', 1, ..., '매장D', nan, '15:34'],
#        ['2018-01-27', '토', 1, ..., nan, nan, nan]], dtype=object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101740 entries, 0 to 101739
# Data columns (total 20 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   공급일자      101740 non-null  object
#  1   요일        101740 non-null  object
#  2   공급월       101740 non-null  int64
#  3   공급주차      101740 non-null  int64
#  4   회원번호      101740 non-null  int64
#  5   조합원상태     101740 non-null  object
#  6   물품대분류     101740 non-null  object
#  7   물품중분류     101739 non-null  object
#  8   물품소분류     101739 non-null  object
#  9   물품명       101739 non-null  object
#  10  구매수량      101739 non-null  float64
#  11  주소-구      101739 non-null  object
#  12  주소-동      101739 non-null  object
#  13  성별        101739 non-null  object
#  14  연령        101739 non-null  float64
#  15  연령대       101739 non-null  object
#  16  구매금액      101739 non-null  float64
#  17  구매매장      101739 non-null  object
#  18  반품_원거래일자  1353 non-null    float64
#  19  구매시각      101739 non-null  object
# dtypes: float64(4), int64(3), object(13)
# memory usage: 15.5+ MB

# %%
df1['구매금액']
# Out:
# 0         22207.0
# 1          4977.0
# 2          7083.0
# 3           766.0
# 4          4403.0
#            ...
# 101735     7466.0
# 101736     4977.0
# 101737     9955.0
# 101738    21441.0
# 101739        NaN
# Name: 구매금액, Length: 101740, dtype: float64

# %%
df1.iloc[1]
# Out:
# 공급일자         2018-01-02
# 요일                    화
# 공급월                   1
# 공급주차                  1
# 회원번호         1506656256
# 조합원상태              정상회원
# 물품대분류                채소
# 물품중분류                버섯
# 물품소분류             느타리버섯
# 물품명         느타리버섯(300g)
# 구매수량                1.0
# 주소-구                수지구
# 주소-동               풍덕천동
# 성별                    여
# 연령                 36.0
# 연령대               30대이하
# 구매금액             4977.0
# 구매매장                매장C
# 반품_원거래일자            NaN
# 구매시각              10:05
# Name: 1, dtype: object

# %%
df2 =df1.iloc[100:]
df2.shape
# Out:
# (101640, 20)

# %%
df1.sort_values(by='구매금액', ascending = False)
# Out:
#               공급일자 요일  공급월  공급주차        회원번호 조합원상태 물품대분류  물품중분류   물품소분류  \
# 81516   2018-01-22  월    1     4  1126443520  정상회원    건강   건강일반  추출/농축액
# 83817   2018-01-22  월    1     4   765542464  정상회원    건강   건강일반  추출/농축액
# 98930   2018-01-26  금    1     4  1505130624  정상회원    건강   건강일반  추출/농축액
# 87371   2018-01-23  화    1     4   656933056  정상회원    건강   건강일반  추출/농축액
# 83286   2018-01-22  월    1     4   355837888  정상회원    건강   건강일반  추출/농축액
# ...            ... ..  ...   ...         ...   ...   ...    ...     ...
# 7611    2018-01-03  수    1     1  1514559104  정상회원  생활용품  식기/편백      무쇠
# 67196   2018-01-18  목    1     3  1442678080  정상회원    건강   건강일반  추출/농축액
# 78130   2018-01-20  토    1     3  1549412928  정상회원    음료     음료      과즙
# 35667   2018-01-10  수    1     2   692739008  정상회원    건강   건강일반  추출/농축액
# 101739  2018-01-27  토    1     4    63308160  정상회원     과    NaN     NaN
#
#                      물품명  구매수량    주소-구 주소-동   성별    연령  연령대      구매금액 구매매장  \
# 81516   흑염소진액(100ml*30봉)   4.0     수지구  상현동    여  41.0  40대  666216.0  매장B
# 83817   흑염소진액(100ml*30봉)   4.0     수지구  상현동    여  50.0  50대  666216.0  매장B
# 98930   흑염소진액(100ml*30봉)   3.0     수지구   기타    여  55.0  50대  499662.0  매장A
# 87371   흑염소진액(100ml*30봉)   3.0     수지구  동천동    여  61.0  60대  499662.0  매장A
# 83286   흑염소진액(100ml*30봉)   3.0  서울 강남구   기타    여  47.0  40대  499662.0  매장B
# ...                  ...   ...     ...  ...  ...   ...  ...       ...  ...
# 7611          무쇠가마솥(5인용)  -1.0      화성   기타    남  40.0  40대 -143581.0  매장D
# 67196      청명차(70ml*30봉)  -1.0     기흥구  동백동    여  51.0  50대 -174977.0  매장C
# 78130   포도즙(팩:120ml*20봉)  -3.0     수지구  신봉동    여  62.0  60대 -178041.0  매장D
# 35667   흑염소진액(100ml*30봉)  -2.0     수지구  동천동    여  64.0  60대 -333108.0  매장A
# 101739               NaN   NaN     NaN  NaN  NaN   NaN  NaN       NaN  NaN
#
#           반품_원거래일자   구매시각
# 81516          NaN  14:45
# 83817          NaN  10:18
# 98930          NaN  15:23
# 87371          NaN  13:15
# 83286          NaN  14:14
# ...            ...    ...
# 7611    20180102.0  16:06
# 67196   20180118.0  12:01
# 78130   20180117.0  17:10
# 35667   20180108.0  15:20
# 101739         NaN    NaN
#
# [101740 rows x 20 columns]

# %%
df1.sort_values(by='구매수량', ascending = False)
# Out:
#               공급일자 요일  공급월  공급주차        회원번호 조합원상태 물품대분류   물품중분류    물품소분류  \
# 97779   2018-01-26  금    1     4   673282560  정상회원    잡곡  콩/화본/깨        콩
# 30565   2018-01-09  화    1     2   478599296    탈퇴    반찬     밑반찬      김가공
# 52256   2018-01-15  월    1     3  1340447744  정상회원   축산물     유제품     요구르트
# 25047   2018-01-08  월    1     2   673726144  정상회원    간식      과자  엿/양갱/기타
# 8020    2018-01-03  수    1     1   120859008  정상회원    간식      과자       스낵
# ...            ... ..  ...   ...         ...   ...   ...     ...      ...
# 3020    2018-01-02  화    1     1  1149018048  정상회원   축산물       소       한우
# 10944   2018-01-04  목    1     1   363143104  정상회원    채소    양념채소       대파
# 29680   2018-01-09  화    1     2   962955904  정상회원    반찬   두부/유부       두부
# 69468   2018-01-18  목    1     3   765542464  정상회원    간식     밀가공   피자/핫도그
# 101739  2018-01-27  토    1     4    63308160  정상회원     과     NaN      NaN
#
#                      물품명  구매수량 주소-구 주소-동   성별    연령    연령대      구매금액 구매매장  \
# 97779        메주콩/유(500g)  30.0  수지구  신봉동    여  76.0  70대이상  315878.0  매장D
# 30565         파래전장김(30g)  24.0  수지구  신봉동    여  83.0  70대이상   96486.0  매장C
# 52256    블루베리요구르트(120ml)  23.0  수지구  죽전동    여  38.0  30대이하   52838.0  매장C
# 25047           팥양갱(40g)  20.0  수지구  신봉동    여  51.0    50대   38288.0  매장D
# 8020         하늘바다새우(60g)  20.0   기타   기타    여  63.0    60대   70833.0  매장C
# ...                  ...   ...  ...  ...  ...   ...    ...       ...  ...
# 3020    한우샤브샤브(300g/국내산)  -5.0  수지구  상현동    여  46.0    40대 -131137.0  매장B
# 10944           대파(500g)  -6.0  수지구  신봉동    여  53.0    50대  -24122.0  매장D
# 29680        두부(1모:420g)  -6.0  수지구  신봉동    여  46.0    40대  -22973.0  매장D
# 69468     한우불고기꼬마피자(88g) -10.0  수지구  상현동    여  50.0    50대  -51689.0  매장B
# 101739               NaN   NaN  NaN  NaN  NaN   NaN    NaN       NaN  NaN
#
#           반품_원거래일자   구매시각
# 97779          NaN  18:01
# 30565          NaN  11:08
# 52256          NaN  16:06
# 25047          NaN  11:21
# 8020           NaN  15:13
# ...            ...    ...
# 3020    20171231.0  19:49
# 10944   20180104.0  16:43
# 29680   20180109.0  12:09
# 69468          NaN  19:11
# 101739         NaN    NaN
#
# [101740 rows x 20 columns]

# %%
df1.sort_values(by=['구매수량','연령'],ascending=[False,True]).iloc[:10]
# Out:
#               공급일자 요일  공급월  공급주차        회원번호 조합원상태 물품대분류   물품중분류    물품소분류  \
# 97779   2018-01-26  금    1     4   673282560  정상회원    잡곡  콩/화본/깨        콩
# 30565   2018-01-09  화    1     2   478599296    탈퇴    반찬     밑반찬      김가공
# 52256   2018-01-15  월    1     3  1340447744  정상회원   축산물     유제품     요구르트
# 95085   2018-01-25  목    1     4   747453888  정상회원    간식      과자  엿/양갱/기타
# 90349   2018-01-24  수    1     4   223961664  정상회원    간식     밀가공       라면
# 97435   2018-01-25  목    1     4   377644032  정상회원    간식     밀가공       라면
# 25047   2018-01-08  월    1     2   673726144  정상회원    간식      과자  엿/양갱/기타
# 100188  2018-01-26  금    1     4   673726144  정상회원    간식      과자  엿/양갱/기타
# 65039   2018-01-17  수    1     3   340848832  정상회원    간식     밀가공       라면
# 8020    2018-01-03  수    1     1   120859008  정상회원    간식      과자       스낵
#
#                       물품명  구매수량 주소-구  주소-동 성별    연령    연령대      구매금액 구매매장  \
# 97779         메주콩/유(500g)  30.0  수지구   신봉동  여  76.0  70대이상  315878.0  매장D
# 30565          파래전장김(30g)  24.0  수지구   신봉동  여  83.0  70대이상   96486.0  매장C
# 52256     블루베리요구르트(120ml)  23.0  수지구   죽전동  여  38.0  30대이하   52838.0  매장C
# 95085          단호박양갱(40g)  20.0   화성    기타  남  45.0    40대   38288.0  매장B
# 90349   우리밀해물라면(114g:1봉지)  20.0   광주   오포읍  여  50.0    50대   53604.0  매장C
# 97435       감자라면(110g:1봉)  20.0  수지구  풍덕천동  여  50.0    50대   49775.0  매장A
# 25047            팥양갱(40g)  20.0  수지구   신봉동  여  51.0    50대   38288.0  매장D
# 100188           팥양갱(40g)  20.0  수지구   신봉동  여  51.0    50대   38288.0  매장D
# 65039    쌀라면/김치맛(114g:1봉)  20.0   기타    기타  여  58.0    50대   53604.0  매장B
# 8020          하늘바다새우(60g)  20.0   기타    기타  여  63.0    60대   70833.0  매장C
#
#         반품_원거래일자   구매시각
# 97779        NaN  18:01
# 30565        NaN  11:08
# 52256        NaN  16:06
# 95085        NaN  17:55
# 90349        NaN  14:36
# 97435        NaN  14:14
# 25047        NaN  11:21
# 100188       NaN  13:08
# 65039        NaN  16:05
# 8020         NaN  15:13

# %%
df1['연령대'].value_counts()

# %%
cond1 = (df1['연령대']=='40대')

# %%
df1.loc[cond1]
# Out:
#               공급일자 요일  공급월  공급주차        회원번호 조합원상태  물품대분류   물품중분류    물품소분류  \
# 0       2018-01-02  화    1     1   272369856  정상회원     과실      과일       사과
# 17      2018-01-02  화    1     1  1049686784  정상회원     간식    식사대용  식사대용/기타
# 18      2018-01-02  화    1     1   164510272  정상회원     채소    양념채소       양파
# 19      2018-01-02  화    1     1  1185171072  정상회원  양념/가루      가루     양념가루
# 20      2018-01-02  화    1     1  1206815744  정상회원     채소    양념채소       대파
# ...            ... ..  ...   ...         ...   ...    ...     ...      ...
# 101720  2018-01-27  토    1     4    72796032  정상회원     과실      견과       호두
# 101728  2018-01-27  토    1     4  1553271552  정상회원     채소    과일채소    방울토마토
# 101732  2018-01-27  토    1     4   622155328  정상회원     채소    양념채소      깐마늘
# 101733  2018-01-27  토    1     4   622155328  정상회원     반찬  절임/장아찌       절임
# 101734  2018-01-27  토    1     4  1144782656  정상회원     간식      과자       스낵
#
#                     물품명  구매수량    주소-구  주소-동 성별    연령  연령대     구매금액 구매매장  \
# 0           사과/유(1.5kg)   1.0     수지구  풍덕천동  여  45.0  40대  22207.0  매장C
# 17         닭고기볶음밥(300g)   1.0     수지구  풍덕천동  여  40.0  40대   5743.0  매장C
# 18              양파(2kg)   1.0     수지구  풍덕천동  여  42.0  40대   8711.0  매장C
# 19         카레(순한맛:100g)   1.0     수지구  풍덕천동  여  47.0  40대   5169.0  매장C
# 20             대파(700g)   1.0     수지구  풍덕천동  여  42.0  40대   5265.0  매장C
# ...                 ...   ...     ...   ... ..   ...  ...      ...  ...
# 101720        깐호두(140g)   1.0     수지구   신봉동  여  47.0  40대  29673.0  매장D
# 101728  방울토마토/대추형(500g)   1.0     수지구   신봉동  여  45.0  40대   6126.0  매장D
# 101732  깐마늘/난지형/유(300g)   1.0     수지구   신봉동  여  46.0  40대  10912.0  매장D
# 101733         무쌈(300g)   1.0     수지구   신봉동  여  46.0  40대   3829.0  매장D
# 101734   우리밀채소쌀건빵(120g)   1.0  서울 강남구    기타  여  43.0  40대   4212.0  매장D
#
#         반품_원거래일자   구매시각
# 0            NaN  10:04
# 17           NaN  10:31
# 18           NaN  10:32
# 19           NaN  10:37
# 20           NaN  10:39
# ...          ...    ...
# 101720       NaN  13:42
# 101728       NaN  14:01
# 101732       NaN  14:39
# 101733       NaN  14:39
# 101734       NaN  14:47
#
# [40570 rows x 20 columns]

# %%
df1.loc[cond1].shape
# Out:
# (40570, 20)

# %%
df1['성별'].value_counts()
# Out:
# 여    95607
# 남     6132
# Name: 성별, dtype: int64

# %%
cond2 = (df1['연령대']=='40대')
cond3 = (df1['성별']=='남')
df1.loc[cond2 & cond3]
# Out:
#               공급일자 요일  공급월  공급주차        회원번호 조합원상태 물품대분류   물품중분류     물품소분류  \
# 34      2018-01-02  화    1     1   570500992  정상회원    간식       떡       즉석떡
# 38      2018-01-02  화    1     1  1314239168  정상회원    간식      과자        스낵
# 196     2018-01-02  화    1     1   850970432  정상회원    채소    뿌리채소        당근
# 197     2018-01-02  화    1     1   850970432  정상회원   축산물       알       유정란
# 328     2018-01-02  화    1     1  1090633856    탈퇴    채소  잎/줄기채소       시금치
# ...            ... ..  ...   ...         ...   ...   ...     ...       ...
# 101375  2018-01-26  금    1     4   762305600  정상회원   축산물     육가공  햄/소시지/훈제
# 101526  2018-01-27  토    1     4   572427520  정상회원    간식     밀가공        라면
# 101527  2018-01-27  토    1     4   572427520  정상회원    채소  잎/줄기채소        아욱
# 101528  2018-01-27  토    1     4   589558400  정상회원    간식       떡       가래떡
# 101625  2018-01-27  토    1     4  1448758336  정상회원    반찬   두부/유부        두부
#
#                      물품명  구매수량 주소-구  주소-동 성별    연령  연령대     구매금액 구매매장  \
# 34              절편(170g)   1.0  수지구  풍덕천동  남  47.0  40대   3829.0  매장C
# 38            밥풀과자(120g)   4.0  수지구   성복동  남  48.0  40대  20676.0  매장C
# 196              당근(1kg)   1.0  기흥구   보정동  남  45.0  40대   4786.0  매장C
# 197     동물복지유정란(10알/국내산)   1.0  기흥구   보정동  남  45.0  40대   6892.0  매장C
# 328            시금치(300g)   1.0  수지구   신봉동  남  41.0  40대   4403.0  매장D
# ...                  ...   ...  ...   ... ..   ...  ...      ...  ...
# 101375  허브맛닭날개양념구이(500g)   1.0  수지구   상현동  남  44.0  40대  19527.0  매장B
# 101526     감자라면(110g:1봉)   1.0  수지구  풍덕천동  남  46.0  40대   2489.0  매장C
# 101527          아욱(300g)   1.0  수지구  풍덕천동  남  46.0  40대   3063.0  매장C
# 101528      떡국떡(유기:800g)   1.0  기흥구    중동  남  42.0  40대  11295.0  매장C
# 101625         순두부(300g)   1.0  수지구  풍덕천동  남  45.0  40대   2010.0  매장C
#
#         반품_원거래일자   구매시각
# 34           NaN  11:19
# 38           NaN  11:22
# 196          NaN  17:11
# 197          NaN  17:11
# 328          NaN  17:09
# ...          ...    ...
# 101375       NaN  19:31
# 101526       NaN  12:04
# 101527       NaN  12:04
# 101528       NaN  12:03
# 101625       NaN  16:12
#
# [1965 rows x 20 columns]
